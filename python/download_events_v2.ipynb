# %% [markdown]
# # Download Events
#
# Download event sessions and event rankings from GP3S using a combination of web scraping and the API.
#
# Copyright 2022 Michael George (AKA Logiqx).
#
# This file is part of GP3S Query and is distributed under the terms of the GNU General Public License.
#
# GP3S Query is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version.
#
# GP3S Query is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details.
#
# You should have received a copy of the GNU General Public License along with GP3S Query. If not, see https://www.gnu.org/licenses/.

# %% [markdown]
# ## API URLs
#
# gps-speedsurfing.com is used for the current event list (web scraping of HTML)
#
# Azure API hosts the GP3S API calls and returns JSON data

# %%
SITES = {
    'gps-speed': 'https://www.gps-speedsurfing.com/default.aspx?mnu=events',
    'gps-foil': 'https://www.gps-foilsurfing.com/default.aspx?mnu=events',
    'gps-wing': 'https://www.gps-wingfoiling.com/default.aspx?mnu=events',
    'gps-kite': 'https://www.gps-kitesurfing.com/default.aspx?mnu=events',
    'gps-ice': 'https://www.gps-icesailing.com/default.aspx?mnu=events'
}

SPEED_TYPES = [
    'speed_100',
    'speed_10sec',
    'speed_24hour',
    'speed_250',
    'speed_2sec',
    'speed_500',
    'speed_alpha_racing',
    'speed_avg',
    'speed_halfhour',
    'speed_hour',
    'speed_mile'
]

API_URL = 'apimgp3s.azure-api.net'

# %% [markdown]
# ## Import Common Modules

# %%
import os
import sys

from datetime import datetime

import http.client
import urllib.request
import urllib.parse

import json

from bs4 import BeautifulSoup

# %% [markdown]
# ## Retrieve Event List

# %%
def getEvents(eventsUrl):
    """Get dictionary of events via simple web scraping"""

    events = {}

    domain = urllib.parse.urlparse(eventsUrl).netloc
    print('Downloading event list from {}'.format(domain))

    req = urllib.request.Request(eventsUrl, headers={'User-Agent': 'Mozilla'})
    response = urllib.request.urlopen(req, timeout = 15)
    
    soup = BeautifulSoup(response, "lxml")

    # Do not assume that the website has running events
    for h3 in soup.find_all("h3", {"class": "panel-title"}):
        if h3.text.strip() in ["Running Events", "Lijst met lopende evenementen"]:
                                #, "Past scheduled Events", "Lijst met historische evenementen"]:
            table = h3.find_next("table", {"id": "eventsTable"})
            anchors = table.find_all("a")
        
            for anchor in anchors:
                event = {}
                event['eventname'] = anchor.text
        
                parsedUrl = urllib.parse.urlparse(anchor.get("href"))
                eventId = urllib.parse.parse_qs(parsedUrl.query)["val"][0]
                
                nameTd = anchor.parent
                startDateTd = nameTd.findNext('td')
                event['start_date'] = datetime.strptime(startDateTd.text.split(' ')[0], '%d-%m-%Y').strftime('%Y-%m-%dT00:00:00')
                endDateTd = startDateTd.findNext('td')
                event['end_date'] = datetime.strptime(endDateTd.text.split(' ')[0], '%d-%m-%Y').strftime('%Y-%m-%dT00:00:00')       
                events[eventId] = event

    return events

# %% [markdown]
# ## Retrieve Events from API

# %%
def getApiData(url, filename, sortKey=None):
    """Get data from the GP3S API"""

    keyPath = os.path.join(projdir, 'keys', 'gp3s')
    with open(keyPath) as f:
        key = f.readline().strip()

    headers = {
        'Ocp-Apim-Subscription-Key': key
    }

    conn = http.client.HTTPSConnection(API_URL)
    conn.request("GET", url, headers=headers)

    response = conn.getresponse()
    if response.status not in [200, 404]:
        print("API response was {} {}".format(response.status, response.reason))
        
    rawData = response.read()
    conn.close()

    if rawData:
        data = json.loads(rawData)
    else:
        data = []
    if sortKey:
        data = sorted(data, key=lambda x: (x[sortKey], x[sortKey]))
    output = json.dumps(data, indent=2)

    dirname = os.path.dirname(filename)
    if not os.path.exists(dirname):
        os.makedirs(dirname)

    with open(filename, "w") as f:
        f.write(output)
        
    return data

# %%
def getEventSessions(apiName, eventId, eventName, service='eventsessions'):
    """Get event sessions from the GP3S API"""

    print('Downloading {} for {}'.format(service, eventName))

    url = "/{}/{}/eventid/{}".format(apiName, service, eventId)
    filename = os.path.join(projdir, 'cache', apiName, service, str(eventId) + '.json')

    sessions = getApiData(url, filename, sortKey='session_id')
        
    return sessions

# %%
def getEventRankings(apiName, eventId, eventName, speedType, service='eventranking'):
    """Get event rankings from the GP3S API"""

    print('Downloading {} for {} - {}'.format(service, eventName, speedType))

    url = "/{}/{}/eventid/{}/speed_type/{}".format(apiName, service, eventId, speedType)
    filename = os.path.join(projdir, 'cache', apiName, service, str(eventId), str(speedType) + '.json')

    rankings = getApiData(url, filename)
        
    return rankings

# %% [markdown]
# ## Download Events

# %%
if __name__ == '__main__':
    projdir = os.path.realpath(os.path.join(sys.path[0], '..'))

    for apiName, eventsUrl in SITES.items():
        events = getEvents(eventsUrl)
        output = json.dumps(events, indent=2)

        filename = os.path.join(projdir, 'cache', apiName, 'events.json')
        dirname = os.path.dirname(filename)
        if not os.path.exists(dirname):
            os.makedirs(dirname)

        with open(filename, "w") as f:
            f.write(output)

        print()

        for eventId, event in events.items():
            eventName = event['eventname']
            sessions = getEventSessions(apiName, eventId, eventName)

            for speedType in SPEED_TYPES:
                getEventRankings(apiName, eventId, eventName, speedType)

            print()
        
    print('All done!')
# Out:
# Downloading event list from www.gps-speedsurfing.com
#
# Downloading eventsessions for 2024 The Summer Edition- Dunkerbeck Speed Challenge
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_100
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_10sec
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_24hour
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_250
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_2sec
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_500
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_avg
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_halfhour
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_hour
# Downloading eventranking for 2024 The Summer Edition- Dunkerbeck Speed Challenge - speed_mile
#
# Downloading eventsessions for 2024 Funworks: TARIFA Speed Champions 2024
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_100
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_10sec
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_24hour
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_250
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_2sec
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_500
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_avg
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_halfhour
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_hour
# Downloading eventranking for 2024 Funworks: TARIFA Speed Champions 2024 - speed_mile
#
# Downloading eventsessions for 2024 Funworks Spanish Speed Champions 2024
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_100
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_10sec
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_24hour
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_250
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_2sec
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_500
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_avg
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_halfhour
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_hour
# Downloading eventranking for 2024 Funworks Spanish Speed Champions 2024 - speed_mile
#
# Downloading eventsessions for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_100
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_10sec
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_24hour
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_250
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_2sec
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_500
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_alpha_racing
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_avg
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_halfhour
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_hour
# Downloading eventranking for 2024 INDIAN OCEAN FAST WINDSURFING GPS CHALLENGE 2024 - speed_mile
#
# Downloading eventsessions for 2024 Prince of Speed GPS Trial 2025
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_100
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_10sec
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_24hour
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_250
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_2sec
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_500
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_alpha_racing
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_avg
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_halfhour
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_hour
# Downloading eventranking for 2024 Prince of Speed GPS Trial 2025 - speed_mile
#
# Downloading eventsessions for 2024 2024 Ho bugt sejlklub, speed konkurence
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_100
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_10sec
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_24hour
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_250
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_2sec
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_500
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_alpha_racing
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_avg
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_halfhour
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_hour
# Downloading eventranking for 2024 2024 Ho bugt sejlklub, speed konkurence - speed_mile
#
# Downloading eventsessions for 2024 Funsport Makkum GPS Speed Challenge
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_100
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_10sec
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_24hour
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_250
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_2sec
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_500
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_avg
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_halfhour
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_hour
# Downloading eventranking for 2024 Funsport Makkum GPS Speed Challenge - speed_mile
#
# Downloading eventsessions for 2024 Wurster Tri-Speed 2024
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_100
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_10sec
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_24hour
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_250
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_2sec
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_500
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_avg
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_halfhour
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_hour
# Downloading eventranking for 2024 Wurster Tri-Speed 2024 - speed_mile
#
# Downloading eventsessions for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_100
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_10sec
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_24hour
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_250
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_2sec
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_500
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_alpha_racing
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_avg
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_halfhour
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_hour
# Downloading eventranking for 2024 forum.timeto.surf GPS-Event fin only - inkl Kombinationswertung - speed_mile
#
# Downloading eventsessions for 2024 2024 Odyssey of Speed
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_100
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_10sec
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_24hour
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_250
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_2sec
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_500
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_alpha_racing
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_avg
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_halfhour
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_hour
# Downloading eventranking for 2024 2024 Odyssey of Speed - speed_mile
#
# Downloading eventsessions for 2024 Singlis Speed Challenge 2024
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_100
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_10sec
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_24hour
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_250
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_2sec
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_500
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_avg
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_halfhour
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_hour
# Downloading eventranking for 2024 Singlis Speed Challenge 2024 - speed_mile
#
# Downloading eventsessions for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_100
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_10sec
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_24hour
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_250
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_2sec
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_500
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_alpha_racing
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_avg
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_halfhour
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_hour
# Downloading eventranking for 2024 2024 Zuidlaardermeer "Berend Botje" Speed Challenge 2024 - speed_mile
#
# Downloading eventsessions for 2024 MAURITIUS SPEED CHALLENGE 2024
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_100
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_10sec
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_24hour
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_250
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_2sec
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_500
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_alpha_racing
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_avg
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_halfhour
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_hour
# Downloading eventranking for 2024 MAURITIUS SPEED CHALLENGE 2024 - speed_mile
#
# Downloading eventsessions for 2024 WSCA Westeinder Speedking 2024
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_100
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_10sec
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_24hour
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_250
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_2sec
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_500
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_alpha_racing
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_avg
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_halfhour
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_hour
# Downloading eventranking for 2024 WSCA Westeinder Speedking 2024 - speed_mile
#
# Downloading eventsessions for 2024 Surf-Forum-One-Hour Challenge
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_100
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_10sec
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_24hour
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_250
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_2sec
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_500
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_alpha_racing
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_avg
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_halfhour
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_hour
# Downloading eventranking for 2024 Surf-Forum-One-Hour Challenge - speed_mile
#
# Downloading eventsessions for 2024 FFF SPEED CHALLENGE
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_100
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_10sec
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_24hour
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_250
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_2sec
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_500
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_alpha_racing
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_avg
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_halfhour
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_hour
# Downloading eventranking for 2024 FFF SPEED CHALLENGE - speed_mile
#
# Downloading eventsessions for 2024 2024 Irish Speed Masters
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_100
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_10sec
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_24hour
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_250
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_2sec
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_500
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_alpha_racing
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_avg
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_halfhour
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_hour
# Downloading eventranking for 2024 2024 Irish Speed Masters - speed_mile
#
# Downloading eventsessions for 2024 Norwegian speedmaster 2024
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_100
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_10sec
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_24hour
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_250
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_2sec
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_500
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_avg
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_halfhour
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_hour
# Downloading eventranking for 2024 Norwegian speedmaster 2024 - speed_mile
#
# Downloading eventsessions for 2024 2024 Gpskraaijchallenge   speedsurfing
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_100
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_10sec
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_24hour
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_250
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_2sec
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_500
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_alpha_racing
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_avg
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_halfhour
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_hour
# Downloading eventranking for 2024 2024 Gpskraaijchallenge   speedsurfing - speed_mile
#
# Downloading eventsessions for 2024 Estonian Speed King 2024
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_100
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_10sec
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_24hour
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_250
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_2sec
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_500
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_alpha_racing
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_avg
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_halfhour
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_hour
# Downloading eventranking for 2024 Estonian Speed King 2024 - speed_mile
#
# Downloading eventsessions for 2024 US Fastest Nautical Mile
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_100
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_10sec
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_24hour
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_250
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_2sec
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_500
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_alpha_racing
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_avg
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_halfhour
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_hour
# Downloading eventranking for 2024 US Fastest Nautical Mile - speed_mile
#
# Downloading eventsessions for 2024 AQUA International Speedsurfing Trophy
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_100
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_10sec
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_24hour
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_250
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_2sec
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_500
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_alpha_racing
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_avg
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_halfhour
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_hour
# Downloading eventranking for 2024 AQUA International Speedsurfing Trophy - speed_mile
#
# Downloading eventsessions for 2023 2023BritishSpeedChalleng2024
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_100
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_10sec
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_24hour
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_250
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_2sec
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_500
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_alpha_racing
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_avg
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_halfhour
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_hour
# Downloading eventranking for 2023 2023BritishSpeedChalleng2024  - speed_mile
#
# Downloading eventsessions for 2023 2023 Schildmeer Speed Challenge 2023-2024
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_100
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_10sec
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_24hour
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_250
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_2sec
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_500
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_alpha_racing
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_avg
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_halfhour
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_hour
# Downloading eventranking for 2023 2023 Schildmeer Speed Challenge 2023-2024 - speed_mile
#
# Downloading eventsessions for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_100
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_10sec
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_24hour
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_250
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_2sec
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_500
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_alpha_racing
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_avg
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_halfhour
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_hour
# Downloading eventranking for 2024 Dunkerbeck Speed Challenge Defi Wind Competitors only  - speed_mile
#
# Downloading eventsessions for 2024 Gran Canaria Dunkerbeck Speed Challenge
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_100
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_10sec
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_24hour
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_250
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_2sec
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_500
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_avg
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_halfhour
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_hour
# Downloading eventranking for 2024 Gran Canaria Dunkerbeck Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 Prince of Speed - World Speed Tour GPS pre World Championship
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_100
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_10sec
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_24hour
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_250
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_2sec
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_500
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_alpha_racing
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_avg
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_halfhour
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_hour
# Downloading eventranking for 2023 Prince of Speed - World Speed Tour GPS pre World Championship - speed_mile
#
# Downloading eventsessions for 2023 Speedfoil Uruguay
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_100
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_10sec
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_24hour
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_250
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_2sec
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_500
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_alpha_racing
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_avg
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_halfhour
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_hour
# Downloading eventranking for 2023 Speedfoil Uruguay - speed_mile
#
# Downloading eventsessions for 2023 “The Third” Dunkerbeck Speed Challenge
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_100
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_10sec
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_24hour
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_250
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_2sec
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_500
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_avg
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_halfhour
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_hour
# Downloading eventranking for 2023 “The Third” Dunkerbeck Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 The RealTrip GPS Speedchallenge
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_100
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_10sec
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_24hour
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_250
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_2sec
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_500
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_alpha_racing
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_avg
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_halfhour
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_hour
# Downloading eventranking for 2023 The RealTrip GPS Speedchallenge - speed_mile
#
# Downloading eventsessions for 2023 2023 Open Dutch Speed Championship (Youth)
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_100
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_10sec
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_24hour
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_250
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_2sec
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_500
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_alpha_racing
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_avg
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_halfhour
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_hour
# Downloading eventranking for 2023 2023 Open Dutch Speed Championship (Youth)  - speed_mile
#
# Downloading eventsessions for 2024 SSS goes Bonaire part I
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_100
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_10sec
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_24hour
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_250
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_2sec
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_500
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_alpha_racing
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_avg
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_halfhour
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_hour
# Downloading eventranking for 2024 SSS goes Bonaire part I - speed_mile
#
# Downloading eventsessions for 2023 SSS goes Egypt part II
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_100
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_10sec
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_24hour
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_250
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_2sec
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_500
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_alpha_racing
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_avg
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_halfhour
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_hour
# Downloading eventranking for 2023 SSS goes Egypt part II - speed_mile
#
# Downloading eventsessions for 2023 2023 Auckland Windsurfing Association Speed Challenge
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_100
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_10sec
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_24hour
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_250
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_2sec
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_500
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_avg
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_halfhour
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_hour
# Downloading eventranking for 2023 2023 Auckland Windsurfing Association Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 Summer Edition- Dunkerbeck Speed Challenge
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_100
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_10sec
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_24hour
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_250
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_2sec
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_500
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_avg
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_halfhour
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_hour
# Downloading eventranking for 2023 Summer Edition- Dunkerbeck Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 2023 Gran Canaria DSC for Defi Wind competitors only
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_100
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_10sec
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_24hour
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_250
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_2sec
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_500
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_alpha_racing
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_avg
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_halfhour
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_hour
# Downloading eventranking for 2023 2023 Gran Canaria DSC for Defi Wind competitors only - speed_mile
#
# Downloading eventsessions for 2023 Ho bugt sejlklub, speed konkurence 2023
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_100
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_10sec
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_24hour
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_250
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_2sec
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_500
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_alpha_racing
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_avg
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_halfhour
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_hour
# Downloading eventranking for 2023 Ho bugt sejlklub, speed konkurence 2023 - speed_mile
#
# Downloading eventsessions for 2023 2023 GpsKraaijchallenge
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_100
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_10sec
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_24hour
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_250
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_2sec
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_500
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_alpha_racing
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_avg
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_halfhour
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_hour
# Downloading eventranking for 2023 2023 GpsKraaijchallenge  - speed_mile
#
# Downloading eventsessions for 2023 Funsport Makkum GPS Speed Challenge
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_100
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_10sec
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_24hour
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_250
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_2sec
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_500
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_avg
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_halfhour
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_hour
# Downloading eventranking for 2023 Funsport Makkum GPS Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 2023 Gran Canara Dunkerbeck Speed Challenge
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_100
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_10sec
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_24hour
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_250
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_2sec
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_500
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_avg
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_halfhour
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_hour
# Downloading eventranking for 2023 2023 Gran Canara Dunkerbeck Speed Challenge - speed_mile
#
# Downloading eventsessions for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_100
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_10sec
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_24hour
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_250
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_2sec
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_500
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_alpha_racing
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_avg
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_halfhour
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_hour
# Downloading eventranking for 2023 UMMAII SPEED CUP - Suhrendorf / Rügen - speed_mile
#
# Downloading eventsessions for 2023 Spanish Challenge
# Downloading eventranking for 2023 Spanish Challenge - speed_100
# Downloading eventranking for 2023 Spanish Challenge - speed_10sec
# Downloading eventranking for 2023 Spanish Challenge - speed_24hour
# Downloading eventranking for 2023 Spanish Challenge - speed_250
# Downloading eventranking for 2023 Spanish Challenge - speed_2sec
# Downloading eventranking for 2023 Spanish Challenge - speed_500
# Downloading eventranking for 2023 Spanish Challenge - speed_alpha_racing
# Downloading eventranking for 2023 Spanish Challenge - speed_avg
# Downloading eventranking for 2023 Spanish Challenge - speed_halfhour
# Downloading eventranking for 2023 Spanish Challenge - speed_hour
# Downloading eventranking for 2023 Spanish Challenge - speed_mile
#
# Downloading eventsessions for 2023 Estonian Speed King 2023
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_100
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_10sec
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_24hour
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_250
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_2sec
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_500
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_alpha_racing
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_avg
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_halfhour
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_hour
# Downloading eventranking for 2023 Estonian Speed King 2023 - speed_mile
#
# Downloading eventsessions for 2023 Odyssey of Speed
# Downloading eventranking for 2023 Odyssey of Speed - speed_100
# Downloading eventranking for 2023 Odyssey of Speed - speed_10sec
# Downloading eventranking for 2023 Odyssey of Speed - speed_24hour
# Downloading eventranking for 2023 Odyssey of Speed - speed_250
# Downloading eventranking for 2023 Odyssey of Speed - speed_2sec
# Downloading eventranking for 2023 Odyssey of Speed - speed_500
# Downloading eventranking for 2023 Odyssey of Speed - speed_alpha_racing
# Downloading eventranking for 2023 Odyssey of Speed - speed_avg
# Downloading eventranking for 2023 Odyssey of Speed - speed_halfhour
# Downloading eventranking for 2023 Odyssey of Speed - speed_hour
# Downloading eventranking for 2023 Odyssey of Speed - speed_mile
#
# Downloading eventsessions for 2023 Lysakerfjordern
# Downloading eventranking for 2023 Lysakerfjordern - speed_100
# Downloading eventranking for 2023 Lysakerfjordern - speed_10sec
# Downloading eventranking for 2023 Lysakerfjordern - speed_24hour
# Downloading eventranking for 2023 Lysakerfjordern - speed_250
# Downloading eventranking for 2023 Lysakerfjordern - speed_2sec
# Downloading eventranking for 2023 Lysakerfjordern - speed_500
# Downloading eventranking for 2023 Lysakerfjordern - speed_alpha_racing
# Downloading eventranking for 2023 Lysakerfjordern - speed_avg
# Downloading eventranking for 2023 Lysakerfjordern - speed_halfhour
# Downloading eventranking for 2023 Lysakerfjordern - speed_hour
# Downloading eventranking for 2023 Lysakerfjordern - speed_mile
#
# Downloading eventsessions for 2023 Wurster Tri-Speed
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_100
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_10sec
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_24hour
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_250
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_2sec
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_500
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_alpha_racing
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_avg
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_halfhour
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_hour
# Downloading eventranking for 2023 Wurster Tri-Speed - speed_mile
#
# Downloading eventsessions for 2023 POINT-7 SLALOM SPEED CUP 023
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_100
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_10sec
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_24hour
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_250
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_2sec
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_500
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_alpha_racing
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_avg
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_halfhour
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_hour
# Downloading eventranking for 2023 POINT-7 SLALOM SPEED CUP 023 - speed_mile
#
# Downloading eventsessions for 2023 USA 100m speed challenge
# Downloading eventranking for 2023 USA 100m speed challenge - speed_100
# Downloading eventranking for 2023 USA 100m speed challenge - speed_10sec
# Downloading eventranking for 2023 USA 100m speed challenge - speed_24hour
# Downloading eventranking for 2023 USA 100m speed challenge - speed_250
# Downloading eventranking for 2023 USA 100m speed challenge - speed_2sec
# Downloading eventranking for 2023 USA 100m speed challenge - speed_500
# Downloading eventranking for 2023 USA 100m speed challenge - speed_alpha_racing
# Downloading eventranking for 2023 USA 100m speed challenge - speed_avg
# Downloading eventranking for 2023 USA 100m speed challenge - speed_halfhour
# Downloading eventranking for 2023 USA 100m speed challenge - speed_hour
# Downloading eventranking for 2023 USA 100m speed challenge - speed_mile
#
# Downloading eventsessions for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga)
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_100
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_10sec
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_24hour
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_250
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_2sec
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_500
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_alpha_racing
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_avg
# Downloading eventranking for 2023 RECHARGE - Speed Challenge 2023 (Preluka - Chiogga) - speed_halfhour
# ...
# Downloading eventranking for 2019 Peet of the Pleet - speed_250
# Downloading eventranking for 2019 Peet of the Pleet - speed_2sec
# Downloading eventranking for 2019 Peet of the Pleet - speed_500
# Downloading eventranking for 2019 Peet of the Pleet - speed_alpha_racing
# Downloading eventranking for 2019 Peet of the Pleet - speed_avg
# Downloading eventranking for 2019 Peet of the Pleet - speed_halfhour
# Downloading eventranking for 2019 Peet of the Pleet - speed_hour
# Downloading eventranking for 2019 Peet of the Pleet - speed_mile
#
# Downloading eventsessions for Singlis Speedchallenge 2019
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_100
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_10sec
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_24hour
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_250
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_2sec
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_500
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_alpha_racing
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_avg
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_halfhour
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_hour
# Downloading eventranking for Singlis Speedchallenge 2019 - speed_mile
#
# Downloading eventsessions for 2019 Channel Islands Speed Challenge
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_100
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_10sec
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_24hour
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_250
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_2sec
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_500
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_alpha_racing
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_avg
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_halfhour
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_hour
# Downloading eventranking for 2019 Channel Islands Speed Challenge - speed_mile
#
# Downloading eventsessions for BALTIC CUP 2019
# Downloading eventranking for BALTIC CUP 2019 - speed_100
# Downloading eventranking for BALTIC CUP 2019 - speed_10sec
# Downloading eventranking for BALTIC CUP 2019 - speed_24hour
# Downloading eventranking for BALTIC CUP 2019 - speed_250
# Downloading eventranking for BALTIC CUP 2019 - speed_2sec
# Downloading eventranking for BALTIC CUP 2019 - speed_500
# Downloading eventranking for BALTIC CUP 2019 - speed_alpha_racing
# Downloading eventranking for BALTIC CUP 2019 - speed_avg
# Downloading eventranking for BALTIC CUP 2019 - speed_halfhour
# Downloading eventranking for BALTIC CUP 2019 - speed_hour
# Downloading eventranking for BALTIC CUP 2019 - speed_mile
#
# Downloading eventsessions for SCHNELLSTER BRETTSEGLER DES OSTENS 2019
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_100
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_10sec
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_24hour
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_250
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_2sec
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_500
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_alpha_racing
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_avg
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_halfhour
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_hour
# Downloading eventranking for SCHNELLSTER BRETTSEGLER DES OSTENS 2019 - speed_mile
#
# Downloading eventsessions for 2019 Mauritius Speed Challenge'
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_100
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_10sec
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_24hour
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_250
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_2sec
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_500
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_alpha_racing
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_avg
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_halfhour
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_hour
# Downloading eventranking for 2019 Mauritius Speed Challenge' - speed_mile
#
# Downloading eventsessions for Intersurf Slotermeer challenge 2019
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_100
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_10sec
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_24hour
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_250
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_2sec
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_500
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_alpha_racing
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_avg
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_halfhour
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_hour
# Downloading eventranking for Intersurf Slotermeer challenge 2019 - speed_mile
#
# Downloading eventsessions for 	2019 Kraaij GPS Challenge
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_100
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_10sec
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_24hour
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_250
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_2sec
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_500
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_alpha_racing
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_avg
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_halfhour
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_hour
# Downloading eventranking for 	2019 Kraaij GPS Challenge - speed_mile
#
# Downloading eventsessions for Norwegian Speedmaster 2019
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_100
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_10sec
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_24hour
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_250
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_2sec
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_500
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_alpha_racing
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_avg
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_halfhour
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_hour
# Downloading eventranking for Norwegian Speedmaster 2019 - speed_mile
#
# Downloading eventsessions for SPEED CHALLENGE BERLIN BRANDENBURG 2019
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_100
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_10sec
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_24hour
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_250
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_2sec
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_500
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_alpha_racing
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_avg
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_halfhour
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_hour
# Downloading eventranking for SPEED CHALLENGE BERLIN BRANDENBURG 2019 - speed_mile
#
# Downloading eventsessions for WSCA Westeinder Speedking 2019
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_100
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_10sec
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_24hour
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_250
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_2sec
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_500
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_alpha_racing
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_avg
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_halfhour
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_hour
# Downloading eventranking for WSCA Westeinder Speedking 2019 - speed_mile
#
# Downloading eventsessions for 2019 FFF SPEED CHALLENGE
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_100
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_10sec
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_24hour
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_250
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_2sec
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_500
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_alpha_racing
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_avg
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_halfhour
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_hour
# Downloading eventranking for 2019 FFF SPEED CHALLENGE  - speed_mile
#
# Downloading eventsessions for Wurster Top 5  2019
# Downloading eventranking for Wurster Top 5  2019 - speed_100
# Downloading eventranking for Wurster Top 5  2019 - speed_10sec
# Downloading eventranking for Wurster Top 5  2019 - speed_24hour
# Downloading eventranking for Wurster Top 5  2019 - speed_250
# Downloading eventranking for Wurster Top 5  2019 - speed_2sec
# Downloading eventranking for Wurster Top 5  2019 - speed_500
# Downloading eventranking for Wurster Top 5  2019 - speed_alpha_racing
# Downloading eventranking for Wurster Top 5  2019 - speed_avg
# Downloading eventranking for Wurster Top 5  2019 - speed_halfhour
# Downloading eventranking for Wurster Top 5  2019 - speed_hour
# Downloading eventranking for Wurster Top 5  2019 - speed_mile
#
# Downloading eventsessions for WSA SPEED CONTEST 2018
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_100
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_10sec
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_24hour
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_250
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_2sec
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_500
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_alpha_racing
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_avg
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_halfhour
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_hour
# Downloading eventranking for WSA SPEED CONTEST 2018 - speed_mile
#
# Downloading eventsessions for 2018 British Speed Championship
# Downloading eventranking for 2018 British Speed Championship - speed_100
# Downloading eventranking for 2018 British Speed Championship - speed_10sec
# Downloading eventranking for 2018 British Speed Championship - speed_24hour
# Downloading eventranking for 2018 British Speed Championship - speed_250
# Downloading eventranking for 2018 British Speed Championship - speed_2sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      20         sessions = getEventSessions(apiName, eventId, eventName)
#      22         for speedType in SPEED_TYPES:
# ---> 23             getEventRankings(apiName, eventId, eventName, speedType)
#      25         print()
#      27 print('All done!')
#
# Cell In[6], line 9, in getEventRankings(apiName, eventId, eventName, speedType, service)
#       6 url = "/{}/{}/eventid/{}/speed_type/{}".format(apiName, service, eventId, speedType)
#       7 filename = os.path.join(projdir, 'cache', apiName, service, str(eventId), str(speedType) + '.json')
# ----> 9 rankings = getApiData(url, filename)
#      11 return rankings
#
# Cell In[4], line 13, in getApiData(url, filename, sortKey)
#       8 headers = {
#       9     'Ocp-Apim-Subscription-Key': key
#      10 }
#      12 conn = http.client.HTTPSConnection(API_URL)
# ---> 13 conn.request("GET", url, headers=headers)
#      15 response = conn.getresponse()
#      16 if response.status not in [200, 404]:
#
# File /opt/conda/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1283 def request(self, method, url, body=None, headers={}, *,
#    1284             encode_chunked=False):
#    1285     """Send a complete request to the server."""
# -> 1286     self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328 if isinstance(body, str):
#    1329     # RFC 2616 Section 3.7.1 says that text default has a
#    1330     # default charset of iso-8859-1.
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279 else:
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 msg = b"\r\n".join(self._buffer)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#    1046     if hasattr(message_body, 'read'):
#    1047         # Let file-like take precedence over byte-like.  This
#    1048         # is needed to allow the current position of mmap'ed
#    1049         # files to be taken into account.
#
# File /opt/conda/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     977 if self.sock is None:
#     978     if self.auto_open:
# --> 979         self.connect()
#     980     else:
#     981         raise NotConnected()
#
# File /opt/conda/lib/python3.11/http/client.py:1451, in HTTPSConnection.connect(self)
#    1448 def connect(self):
#    1449     "Connect to a host on a given (SSL) port."
# -> 1451     super().connect()
#    1453     if self._tunnel_host:
#    1454         server_hostname = self._tunnel_host
#
# File /opt/conda/lib/python3.11/http/client.py:945, in HTTPConnection.connect(self)
#     943 """Connect to the host and port specified in __init__."""
#     944 sys.audit("http.client.connect", self, self.host, self.port)
# --> 945 self.sock = self._create_connection(
#     946     (self.host,self.port), self.timeout, self.source_address)
#     947 # Might fail in OSs that don't implement TCP_NODELAY
#     948 try:
#
# File /opt/conda/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     834 if source_address:
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#     838 exceptions.clear()
#
# KeyboardInterrupt:
